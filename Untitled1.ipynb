# %%
my_tractor = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/dr8_test/tractor/127/tractor-1273p255.fits'
dr8 = '/global/project/projectdirs/cosmo/data/legacysurvey/dr8/south/tractor/127/tractor-1273p255.fits'

# %%
# %pylab inline
import matplotlib.pyplot as plt
import astropy.io.fits as fits
dat = fits.getdata(my_tractor)
dr8 = fits.getdata(dr8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure(figsize=(7,7))
plt.plot(dat['ra'],dat['dec'],'r.')
plt.plot(dr8['ra'],dr8['dec'],'b+')

# %%
(dr8['shapeexp_e1']-dat['shapeexp_e1']).max()
# Out:
# 2.3722649e-05
