# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
import astropy.io.fits as fits
from astropy.table import Table
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#make error bars for x0
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[1]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

# %%
#xi0
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr1 = corr_dir+'chunk23_v16_obiwan_weight_obiwan.out'
corr2 = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/3d_corr/data/xi0gebossELG_NGC4_mz0.6xz1.1fkp8st0.dat'
corr3=corr_dir+'chunk23_v16_weight_systot_obiwan.out'
corr8 = corr_dir+'elg_clustering_chunk23_w_edge_uniform_uniform.out'
d1=np.loadtxt(corr1).transpose()
d2=np.loadtxt(corr2).transpose()
d3=np.loadtxt(corr3).transpose()
d8=np.loadtxt(corr8).transpose()
plt.plot(d1[0][:25],d1[1][:25]*d1[0][:25]*d1[0][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d3[0][:25],d3[1][:25]*d3[0][:25]*d3[0][:25],std_list*d3[0][:25]*d3[0][:25],label='weight systot',linestyle='--',marker='.')
plt.plot(d8[0][:25],d8[1][:25],label='uniform',linestyle='--',marker='.')
#plt.plot(d2[0],d2[1]*d2[0]*d2[0],label='original')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r^2 \mathit{\xi_0(r)}$'+' '+r'$Mpc^2h^{-2}}$')
plt.title('ELG ngc chunk23')
# Out:
# Text(0.5,1,'ELG ngc chunk23')

# %%
#make error bars for x2
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

# %%
plt.plot(x,y/len(y_i))

# %%
#xi2
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_clustering_chunk23_w_edge_uniform_order2.out'
corr5 = corr_dir+'elg_clustering_chunk23_w_edge_weight_systot_uniform_order2.out'
corr6 = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/3d_corr/data/xi2gebossELG_eboss234_mz0.6xz1.1fkp8st0.dat'
corr7 = corr_dir+'elg_clustering_chunk23_w_edge_uniform_uniform_order2.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()
d6=np.loadtxt(corr6).transpose()
d7 = np.loadtxt(corr7).transpose()
plt.plot(d4[0][:25],d4[1][:25]*2/d4[0][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25]*2/d5[0][:25],std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*2/d7[0][:25],label='uniform',linestyle='--',marker='.')
#plt.errorbar(d6[0],d6[1]*d6[0],label='original',marker='.')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_2(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('elg NGC chunk23')
# Out:
# Text(0.5,1,'elg NGC chunk23')

# %%
#make error bars for xi4
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF2/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

# %%
plt.plot(x,y/len(y_i))

# %%
#xi4
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_clustering_chunk23_w_edge_uniform_order4.out' #good
corr5 = corr_dir+'elg_clustering_chunk23_w_edge_weight_systot_uniform_order4.out' #good
corr6 = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/3d_corr/data/xi2gebossELG_eboss234_mz0.6xz1.1fkp8st0.dat'
corr7 = corr_dir+'elg_clustering_chunk23_w_edge_uniform_uniform_order4.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()
d6=np.loadtxt(corr6).transpose()
d7 = np.loadtxt(corr7).transpose()
plt.plot(d4[0][:25],d4[1][:25]*2/d4[0][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25]*2/d5[0][:25],std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*2/d7[0][:25],label='uniform',linestyle='--',marker='.')
#plt.errorbar(d6[0],d6[1]*d6[0],label='original',marker='.')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_4(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('elg NGC chunk23')
# Out:
# Text(0.5,1,'elg NGC chunk23')

# %%
#angcorr
angdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/corr_output/'
fn=angdir+'elg_ngc_run_obiwan.out'
fn2=angdir+'elg_ngc_run_uniform_real.out'
fn3=angdir+'weight_systot_for_corr_uniform.out'
ang1 = np.loadtxt(fn)
ang2=np.loadtxt(fn2)
ang3=np.loadtxt(fn3)
plt.errorbar(ang1[0],ang1[1]*ang1[0],ang1[2]*ang1[0],label='obiwan')
plt.errorbar(ang2[0],ang2[1]*ang2[0],ang2[2]*ang2[0],label='uniform')
plt.errorbar(ang3[0],ang3[1]*ang3[0],ang3[2]*ang3[0],label='weight systot')
plt.legend()
plt.gca().set_xscale('log')
plt.xlabel(r'$\theta$')
plt.ylabel('w('+r'$\theta$'+')')
plt.title('elg NGC chunk23')
# Out:
# Text(0.5,1,'elg NGC chunk23')

# %%
topdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/sys-analysis/data/'
fn1='hpstardens_sys_weight_systot.dat'
fn2='hpstardens_sys_obiwan_weight.dat'
fn3='hpstardens_sys_uniform.dat'
dat1 = np.loadtxt(topdir+fn1).transpose()
dat2 = np.loadtxt(topdir+fn2).transpose()
dat3 = np.loadtxt(topdir+fn3).transpose()
plt.errorbar(dat2[0],dat2[1],dat2[2], label = 'obiwan_weight',linestyle='--',marker='.')
plt.errorbar(dat1[0],dat1[1],dat1[2],label = 'weight_systot',linestyle='--',marker='.')
plt.errorbar(dat3[0],dat3[1],dat3[2], label = 'uniform',linestyle='--',marker='.')
plt.legend()
plt.xlabel('star density')
plt.plot(dat1[0],np.ones_like(dat1[0]),linestyle='--',color='k')

# %%
topdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/sys-analysis/data/'
fn1='hpebv_sys_weight_systot.dat'
fn2='hpebv_sys_obiwan_weight.dat'
fn3='hpebv_sys_uniform.dat'
dat1 = np.loadtxt(topdir+fn1).transpose()
dat2 = np.loadtxt(topdir+fn2).transpose()
dat3 = np.loadtxt(topdir+fn3).transpose()
plt.errorbar(dat2[0],dat2[1],dat2[2], label = 'obiwan_weight',linestyle='--',marker='.')
plt.errorbar(dat1[0],dat1[1],dat1[2],label = 'weight_systot',linestyle='--',marker='.')
plt.errorbar(dat3[0],dat3[1],dat3[2], label = 'uniform',linestyle='--',marker='.')
plt.legend()
plt.xlabel('extinction')
plt.plot(dat1[0],np.ones_like(dat1[0]),linestyle='--',color='k')

# %%
#made with obiwan2weight.py in angcorr/
plt.figure(figsize = ((7,5)))
topdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/ang_corr/plots/'
data_density_chunk23 = np.loadtxt(topdir+'data_density_chunk23.txt')
plt.scatter(data_density_chunk23[0],data_density_chunk23[1],c=data_density_chunk23[2],\
vmin=data_density_chunk23[2].mean()-1.5*data_density_chunk23[2].std(),
            vmax=data_density_chunk23[2].mean()+1.5*data_density_chunk23[2].std(),
           marker='p',s=60)
plt.title('ELG density (chunk23)')
plt.xlabel('ra')
plt.ylabel('dec')
plt.colorbar()

# %%
plt.figure(figsize = ((7,5)))
topdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/ang_corr/plots/'
data_density_chunk23 = np.loadtxt(topdir+'obiwan_density_chunk23.txt')
plt.scatter(data_density_chunk23[0],data_density_chunk23[1],c=data_density_chunk23[2],\
vmin=data_density_chunk23[2].mean()-1.5*data_density_chunk23[2].std(),
            vmax=data_density_chunk23[2].mean()+1.5*data_density_chunk23[2].std(),
           marker='p',s=60)
plt.title('Obiwan density (chunk23)')
plt.xlabel('ra')
plt.ylabel('dec')
plt.colorbar()

# %%
#ccd density
topdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_data/legacysurveydir_dr3/c-c-d-s/'
ccd_dr3 = fits.getdata(topdir+'survey-ccds-ebossDR3_dr3.fits.gz')
plt.plot(ccd_dr3['ra'][ccd_dr3['dec']>10],ccd_dr3['dec'][ccd_dr3['dec']>10],'k,')
plt.title('CCD density (chunk23)')
plt.xlabel('ra')
plt.ylabel('dec')
# Out:
# Text(0,0.5,'dec')

# %%
#actual ccd is divided into 2 parts, blacks processed at nersc, reds processed in utah,
#but I combine them into one ccd file. From the output, this doesn't seem to matter a lot
topdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_data/ebosselg_ccds/'
ccd_utah = fits.getdata(topdir+'survey-ccds-dr3_utah_ngc.fits.gz')
ccd_nersc = fits.getdata(topdir+'survey-ccds-dr3.fits.gz')
plt.plot(ccd_nersc['ra'][ccd_nersc['dec']>10],ccd_nersc['dec'][ccd_nersc['dec']>10],'k,')
plt.plot(ccd_utah['ra'][ccd_utah['dec']>10],ccd_utah['dec'][ccd_utah['dec']>10],'r,')

# %%
#check mophorlogical bias sqrt(e1^2+e2^2)
#output is more round than input
plt.figure(figsize(5,4))
topdir='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/subset/'
fn =  'eBOSS_ELG_full_ALL_v4.dat_really_masked_chunk23_elg_ngc_run_part1.fits'
fn_obiwan = 'elg_ngc_run_chunk23_really_masked_combined.fits'
fn_sim = 'sim_elg_ngc_run_chunk23_really_masked_combined.fits'
DAT = fits.getdata(topdir+fn)
obiwan = fits.getdata(topdir+fn_obiwan)
sim = fits.getdata(topdir+fn_sim)

#data = fits.getdata(topdir+)
#exp
exp = obiwan[obiwan['fracdev']<0.5]
output=np.sqrt(exp['shapeexp_e1']**2+exp['shapeexp_e2']**2)-np.sqrt(exp['sim_e1']**2+exp['sim_e2']**2)
p=plt.hist(output,bins=20)
print(output.mean())
plt.xlabel(r'$\Delta \sqrt{e_1^2+e_2^2}$, output-input within ELG selection')
plt.title('exp: shape tend to be more round after selection')
# Out:
# -0.239114469834
# /global/common/software/desi/cori/desiconda/20180709-1.2.6-spec/conda/lib/python3.6/site-packages/ipykernel/__main__.py:15: RuntimeWarning: invalid value encountered in sqrt
# Text(0.5,1,'exp: shape tend to be more round after selection')

# %%
#dev
plt.figure(figsize(5,5))
#dev
dev = obiwan[obiwan['fracdev']>0.5]
output=np.sqrt(dev['shapedev_e1']**2+dev['shapedev_e2']**2)-np.sqrt(dev['sim_e1']**2+dev['sim_e2']**2)
p=plt.hist(output,bins=20)
print(output.mean())
plt.xlabel(r'$\Delta \sqrt{e_1^2+e_2^2}$, output-input within ELG selection')
plt.title('shape tend to be more round after selection')
# Out:
# -0.201086098837
# Text(0.5,1,'shape tend to be more round after selection')

# %%
len(obiwan)
# Out:
# 86923

# %%
def mag(mag,Type,data=obiwan): #Type='sim'/'obiwan'
    if Type is 'obiwan':
        mag_input = data
        g     = 22.5 - 2.5 * np.log10(data['flux_g'] / data['mw_transmission_g'])
        r_mag = 22.5 - 2.5 * np.log10(data['flux_r'] / data['mw_transmission_r'])
        z_mag = 22.5 - 2.5 * np.log10(data['flux_z'] / data['mw_transmission_z'])
        if mag == 'g':
            return g
        if mag == 'r':
            return r_mag
        if mag == 'z':
            return z_mag
    if Type is 'sim':
        g     = 22.5 - 2.5 * np.log10(data['sim_gflux'] / data['sim_mw_transmission_g'])
        r_mag = 22.5 - 2.5 * np.log10(data['sim_rflux'] / data['sim_mw_transmission_r'])
        z_mag = 22.5 - 2.5 * np.log10(data['sim_zflux'] / data['sim_mw_transmission_z'])
        if mag == 'g':
            return g
        if mag == 'r':
            return r_mag
        if mag == 'z':
            return z_mag

# %%
#flux bias
plt.figure(figsize(7,12))
plt.subplot(3,2,1)
plt.hist(mag('g','obiwan')-mag('r','obiwan')-mag('g','sim')+mag('r','sim'),bins=20)
mean=(mag('g','obiwan')-mag('r','obiwan')-mag('g','sim')+mag('r','sim')).mean()
std=(mag('g','obiwan')-mag('r','obiwan')-mag('g','sim')+mag('r','sim')).std()
print(r'g-r:%f+/-%f'%(mean,std))
plt.title(r'$\Delta (g-r),output-input$')
plt.subplot(3,2,2)
plt.hist(mag('g','obiwan')-mag('r','sim'),label='output',density=True,bins=20)
plt.hist(mag('g','sim')-mag('r','sim'),alpha=0.5,label='input',density=True,bins=20)
plt.legend()
plt.title('g-r')
plt.subplot(3,2,3)
plt.hist(mag('r','obiwan')-mag('z','obiwan')-mag('r','sim')+mag('z','sim'),bins=20)
plt.title(r'$\Delta (r-z),output-input$')
mean=(mag('r','obiwan')-mag('z','obiwan')-mag('r','sim')+mag('z','sim')).mean()
std=(mag('r','obiwan')-mag('z','obiwan')-mag('r','sim')+mag('z','sim')).std()
print('r-z:%f+/-%f'%(mean,std))
plt.subplot(3,2,4)
plt.hist(mag('r','obiwan')-mag('z','obiwan'),label='output',density=True,bins=20)
plt.hist(mag('r','sim')-mag('z','sim'),alpha=0.5,label='input',density=True,bins=20)
plt.legend()
plt.title('r-z')
print('g-r,r-z is close enough to original distribution')

plt.subplot(3,2,5)
plt.hist(mag('g','obiwan')-mag('g','sim'),bins=20)
plt.title('$\Delta$g,output-input')
mean=(mag('g','obiwan')-mag('g','sim')).mean()
std=(mag('g','obiwan')-mag('g','sim')).std()
print('g:%f+/-%f'%(mean,std))

plt.subplot(3,2,6)
plt.hist(mag('g','obiwan'),bins=20,label='output')
plt.hist(mag('g','sim'),bins=20,alpha=0.5,label='input')
plt.legend()
plt.title('$\Delta$g, output-input')
mean=(mag('g','obiwan')-mag('g','sim')).mean()
std=(mag('g','obiwan')-mag('g','sim')).std()
print('g:%f+/-%f'%(mean,std))
# Out:
# g-r:-0.022038+/-0.115030
# r-z:0.058188+/-0.115137
# g-r,r-z is close enough to original distribution
# g:0.087079+/-0.192009
# g:0.087079+/-0.192009

# %%
'''
I think it's hard to use obiwan to measure how the profile 'truly' changes because of measurement error 
in legacypipe bias. instead, obiwan should make targets that mimic properties of galaxies when it goes to output
'''

# %%
#magnitude offset
chunk='chunk23'
def MAG(mag, Type):
    if Type=='obiwan':
        data=obiwan
        g     = 22.5 - 2.5 * np.log10(data['flux_g'] / data['mw_transmission_g'])
        r_mag = 22.5 - 2.5 * np.log10(data['flux_r'] / data['mw_transmission_r'])
        z_mag = 22.5 - 2.5 * np.log10(data['flux_z'] / data['mw_transmission_z'])
    if Type=='sim':
        data=obiwan
        g     = 22.5 - 2.5 * np.log10(data['sim_gflux'] / data['sim_mw_transmission_g'])
        r_mag = 22.5 - 2.5 * np.log10(data['sim_rflux'] / data['sim_mw_transmission_r'])
        z_mag = 22.5 - 2.5 * np.log10(data['sim_zflux'] / data['sim_mw_transmission_z'])
    if Type=='uniform':
        data = sim
        g     = 22.5 - 2.5 * np.log10(data['gflux'] / data['mw_transmission_g'])
        r_mag = 22.5 - 2.5 * np.log10(data['rflux'] / data['mw_transmission_r'])
        z_mag = 22.5 - 2.5 * np.log10(data['zflux'] / data['mw_transmission_z'])
    if mag == 'g':
        return g
    if mag == 'r':
        return r_mag
    if mag == 'z':
        return z_mag
    

    
def offset(mag, plot_index, data = obiwan):
    plt.subplot(2,2,plot_index)
    mag_diff = MAG(mag,'obiwan') - MAG(mag,'sim')
    n, bins, patches = plt.hist(mag_diff,bins = 50,normed = True)
    y = np.arange(n.max()+1)
    x = np.zeros(len(y))
    plt.plot(x,y)
    plt.xlabel(chunk)
    plt.title('mag diff (output-input), %s band \n offset: %.3f std: %.3f' % (mag, mag_diff.mean(), mag_diff.std()))
plt.figure(figsize = (9,7))
offset('g',1)
offset('r',2)
offset('z',3)
plt.tight_layout()

# %%
def mag_dist(mag,plt_idx, data = obiwan):
    mag_diff = MAG(mag,'obiwan') - MAG(mag,'sim')
    sup = mag_diff.mean() + mag_diff.std()
    inf = mag_diff.mean() - mag_diff.std()
    sel = (mag_diff<sup)&(mag_diff>inf)
    dat_sel = data[sel==False] 
    plt.subplot(2,2,plt_idx)
    plt.hexbin(dat_sel['ra'],dat_sel['dec'],gridsize = 50, cmap = 'jet',vmin=5)
    plt.colorbar()
    plt.xlabel(chunk)
    plt.title('# of obiwan outputs '+mag+' band mag outside 1 sig')    

plt.figure(figsize = (10,8))
mag_dist('g',1)
mag_dist('r',2)
mag_dist('z',3)
plt.tight_layout()

# %%
def mag_alg_hist(TYPE, plt_idx, data = obiwan):
    plt.subplot(3,2,plt_idx)
    bin_arg = dict(bins = 50, stacked = False, normed=True)
    if TYPE == 'g-r':
        #g-r hist input,output (to ELG cut)
        plt.hist(MAG('g','obiwan')-MAG('r','obiwan'),label = 'output', **bin_arg)
        plt.hist(MAG('g','sim') - MAG('r','sim'), label = 'input, after ELG cut',alpha = 0.5, **bin_arg)
        plt.hist(MAG('g','uniform') - MAG('r','uniform'), label = 'input, before ELG cut', alpha=0.5, **bin_arg)
        plt.legend()
        plt.title('g-r mag ' + chunk)
    elif TYPE == 'r-z':
        #r-z hist input,output (to ELG cut)
        plt.hist(MAG('r','obiwan')-MAG('z','obiwan'),label = 'output', **bin_arg)
        plt.hist(MAG('r','sim') - MAG('z','sim'), label = 'input, after ELG cut',alpha=0.5, **bin_arg)
        plt.hist(MAG('r','uniform') - MAG('z','uniform'), label = 'input, before ELG cut', alpha=0.5, **bin_arg)
        plt.legend()
        plt.title('r-z mag, chunk23') 
    else:
        assert(TYPE in ['g','r','z'])
        plt.hist(MAG(TYPE,'obiwan'),label = 'output', **bin_arg)
        plt.hist(MAG(TYPE,'sim'), label = 'input, after ELG cut',alpha=0.5, **bin_arg)
        plt.hist(MAG(TYPE,'uniform'), label = 'input, before ELG cut',alpha=0.5, **bin_arg)
        plt.legend()
        plt.title(TYPE+' mag '+chunk)
plt.figure(figsize = (10,15))
mag_alg_hist('g-r',1)
mag_alg_hist('r-z',2)
mag_alg_hist('g',3)
mag_alg_hist('r',4)
mag_alg_hist('z',5)

# %%
def mag_alg_hist(TYPE, plt_idx, data = obiwan):
    plt.subplot(3,2,plt_idx)
    bin_arg = dict(bins = 50, stacked = False, normed=True)
    if TYPE == 'g-r':
        #g-r hist input,output (to ELG cut)
        plt.hist(MAG('g','obiwan')-MAG('r','obiwan'),label = 'output', **bin_arg)
        plt.hist(MAG('g','sim') - MAG('r','sim'), label = 'input, after ELG cut',alpha = 0.5, **bin_arg)
        plt.hist(MAG('g','uniform') - MAG('r','uniform'), label = 'input, before ELG cut', alpha=0.5, **bin_arg)
        plt.legend()
        plt.title('g-r mag ' + chunk)
    elif TYPE == 'r-z':
        #r-z hist input,output (to ELG cut)
        plt.hist(MAG('r','obiwan')-MAG('z','obiwan'),label = 'output', **bin_arg)
        plt.hist(MAG('r','sim') - MAG('z','sim'), label = 'input, after ELG cut',alpha=0.5, **bin_arg)
        plt.hist(MAG('r','uniform') - MAG('z','uniform'), label = 'input, before ELG cut', alpha=0.5, **bin_arg)
        plt.legend()
        plt.title('r-z mag, chunk23') 
    else:
        assert(TYPE in ['g','r','z'])
        plt.hist(MAG(TYPE,'obiwan'),label = 'output', **bin_arg)
        plt.hist(MAG(TYPE,'sim'), label = 'input, after ELG cut',alpha=0.5, **bin_arg)
        plt.hist(MAG(TYPE,'uniform'), label = 'input, before ELG cut',alpha=0.5, **bin_arg)
        plt.legend()
        plt.title(TYPE+' mag '+chunk)
plt.figure(figsize = (10,15))
mag_alg_hist('g-r',1)
mag_alg_hist('r-z',2)
mag_alg_hist('g',3)
mag_alg_hist('r',4)
mag_alg_hist('z',5)

# %%
sim_m=sim
def compare_obiwan(res = 256, obiwan = obiwan):
    import healpy as hp
    #mean <mag-mag_true> plot g,r,z
    pixs = hp.ang2pix(res,obiwan['ra'],obiwan['dec'],nest = True, lonlat = True)
    pixs2 = hp.ang2pix(res,sim_m['ra'], sim_m['dec'], nest = True, lonlat = True)
    pixs3 = hp.ang2pix(res,DAT['ra'],DAT['dec'],nest = True, lonlat = True)
    N = 12*res**2
    hist_n = np.zeros(N)
    hist_mag_diff_g = np.zeros(N)
    hist_mag_diff_r = np.zeros(N)
    hist_mag_diff_z = np.zeros(N)
    mag_g = MAG('g','obiwan')
    mag_r =  MAG('r', 'obiwan')
    mag_z = MAG('z', 'obiwan')
    sim_mag_g =  MAG('g','sim')
    sim_mag_r =  MAG('r','sim')
    sim_mag_z =  MAG('z','sim')
    for i in range(len(pixs)):
        n = pixs[i]
        mag_diff_g = mag_g[i] - sim_mag_g[i]
        mag_diff_r = mag_r[i] - sim_mag_r[i]
        mag_diff_z = mag_z[i] - sim_mag_z[i]
        hist_mag_diff_g[n]+=mag_diff_g
        hist_mag_diff_r[n]+=mag_diff_r
        hist_mag_diff_z[n]+=mag_diff_z
        hist_n[n]+=1
    hist2 = np.zeros(N)
    for i in range(len(pixs2)):
        n = pixs2[i]
        hist2[n]+=1
    hist3 = np.zeros(N)
    for i in range(len(pixs3)):
        n = pixs3[i]
        hist3[n]+=1
        
    N = 12*res**2
    ra,dec = hp.pix2ang(res,np.arange(N), nest = True,lonlat = True)
    col1 = fits.Column(name = 'ra', array = ra, format = 'D')
    col2 = fits.Column(name = 'dec', array = dec, format = 'D')
    # # of obiwans in each pixel
    col3 = fits.Column(name = 'num_obiwan', array = hist_n, format = 'D')
    col4 = fits.Column(name = 'hist_mag_diff_g', array = hist_mag_diff_g, format = 'D')
    col5 = fits.Column(name = 'hist_mag_diff_r', array = hist_mag_diff_r, format = 'D')
    col6 = fits.Column(name = 'hist_mag_diff_z', array = hist_mag_diff_z, format = 'D')
    # # of uniform randoms in each pixel
    col7 = fits.Column(name = 'num_uniform', array = hist2, format = 'D')
    # # of real elgs in each pixel
    col8 = fits.Column(name = 'num_elgs', array = hist3, format = 'D')
    
    #bad pixels
    g = sim_mag_g
    rz = sim_mag_r - sim_mag_z
    gr = sim_mag_g - sim_mag_r
    color_sgc = (g>21.825)&(g<22.825)&(-0.068*rz+0.457<gr)&(gr< 0.112*rz+0.773) &(0.218*gr+0.571<rz)&(rz<-0.555*gr+1.901)
    dat_bad = obiwan[color_sgc==False]
    pixs_bad = hp.ang2pix(res,dat_bad['ra'],dat_bad['dec'],nest = True, lonlat = True)
    hist_bad = np.zeros(N)
    for i in range(len(pixs_bad)):
        n = pixs_bad[i]
        hist_bad[n]+=1
    col9 = fits.Column(name = 'num_bad', array = hist_bad, format = 'D')
    dat = fits.BinTableHDU.from_columns([col1,col2,col3,col4,col5,col6,col7,col8,col9]).data
    uni = dat['num_uniform']
    sel = (uni>0)
    return dat[sel]
#obiwan rearanged in healpix format
compact_obiwan = compare_obiwan()

# %%
plt.figure(figsize=(3,2))
pt = plt.hist(compact_obiwan['num_uniform'],bins=50)
#have a cut @ 30
def cut_uni(cut_set = 50):
    uni = compact_obiwan['num_uniform']
    sel = (uni>cut_set)
    hp_obiwan = compact_obiwan[sel]
    return hp_obiwan
hp_obiwan = cut_uni()

# %%
import healpy as hp
N = 12*128**2
pixs2 = hp.ang2pix(128,sim_m['ra'], sim_m['dec'], nest = True, lonlat = True)
hist2 = np.zeros(N)

for i in range(364061):
        n = pixs2[i]
        hist2[n]+=1

# %%
#number density fluctuation
def nb_dens_fluc(TYPE,plt_idx,data = hp_obiwan):
    plt.subplot(3,2,plt_idx)
    assert(TYPE in ['obiwan','elgs','obiwan-0.6<z<1.1'])
    if TYPE == 'obiwan' or TYPE == 'obiwan-0.6<z<1.1':
        color = data['num_obiwan']/data['num_uniform']
    else:
        color = data['num_elgs']/data['num_uniform']
    mean = color.mean()
    std = color.std()
    plt.scatter(data['ra'],data['dec'],c=color-mean,cmap = 'seismic',vmin = -std*1.5,vmax = 1.5*std,marker='.')
    plt.colorbar()
    plt.title('dens fluct '+ TYPE +' substract mean: %.3f, +/- 1.5 sigma' % mean)
    plt.subplot(3,2,plt_idx+1)
    plt.hist(color-mean,bins = 20)
    std = (color-mean).std()
    plt.title('density hist of '+ TYPE +' std: %.3f' % std)
plt.figure(figsize = (10,12))
nb_dens_fluc('obiwan',1)
nb_dens_fluc('elgs',3)



#number density fluctuation for obiwan at 0.6<z<1.1
def nb_dens_fluc_w_redshift_cut(plt_idx = 5, z_min = 0.6,zmax = 1.1):
    redshift = obiwan['redshift']
    obiwan_sel = (redshift<1.1)&(redshift>0.6)
    obiwan_rf_cut = obiwan[obiwan_sel]
    obiwan_rf_cutted = compare_obiwan(res = 128, obiwan = obiwan_rf_cut)
    uni = obiwan_rf_cutted['num_uniform']
    sel = (uni>350)
    hp_obiwan_cutted = compact_obiwan[sel]
    plt.subplot(3,2,plt_idx)
    nb_dens_fluc('obiwan-0.6<z<1.1',plt_idx,data = hp_obiwan_cutted)

#nb_dens_fluc_w_redshift_cut()
plt.tight_layout()

# %%
def plt_gen(Color, plt_idx, dat = hp_obiwan):
    plt.subplot(3,2,plt_idx)
    color = dat['hist_mag_diff_'+Color]/dat['num_obiwan']
    mean,std = color.mean(),color.std()
    sc = plt.scatter(hp_obiwan['ra'],hp_obiwan['dec'],c=color,vmin = mean-2*std, vmax = mean+2*std,marker='.')
    plt.colorbar(sc)
    plt.title(Color+' mag diff +/- 2*sigma')
    plt.subplot(3,2,plt_idx+1)
    pt = plt.hist(color,bins = 50)
    plt.title(Color+' mag diff hist, mean: %.3f, std: %.3f' % (mean,std))

plt.figure(figsize=(10,12))    
plt_gen('g',1)
plt_gen('r',3)
plt_gen('z',5)

# %%
#bad pixel map, bad means not obiwan but get inside the selection box
def bd_pix_plt_gen(dat = hp_obiwan):
    plt.subplot(1,2,1)
    color = dat['num_bad']/dat['num_obiwan']
    mean,std = color.mean(),color.std()
    sc = plt.scatter(hp_obiwan['ra'],hp_obiwan['dec'],c=color,cmap = 'cool',vmin = mean-2*std, vmax = mean+2*std,marker='.')
    plt.colorbar(sc)
    plt.title('bad pixel map +/- 2*sigma')
    plt.subplot(1,2,2)
    pt = plt.hist(color,bins = 50)
    plt.title('bad pixel hist, mean: %.3f, std: %.3f' % (mean,std))
plt.figure(figsize = (10,4))
bd_pix_plt_gen()
plt.tight_layout()

# %%
#this hist is averaged in each pixel
pixs = hp.ang2pix(128,obiwan['ra'],obiwan['dec'],nest = True, lonlat = True)
N = 12*128**2
hist_n = np.zeros(N)
hist_mag_diff_g = np.zeros(N)
hist_mag_diff_r = np.zeros(N)
hist_mag_diff_z = np.zeros(N)
mag_g = mag('g','obiwan')
mag_r =  mag('r','obiwan')
mag_z = mag('z','obiwan')

mag_g_sim = mag('g','sim')
mag_r_sim =  mag('r','sim')
mag_z_sim = mag('z','sim')

for i in range(len(pixs)):
    n = pixs[i]
    mag_diff_g = mag_g[i] - mag_g_sim[i]
    mag_diff_r = mag_r[i] - mag_r_sim[i]
    mag_diff_z = mag_z[i] - mag_z_sim[i]
    hist_mag_diff_g[n]+=mag_diff_g
    hist_mag_diff_r[n]+=mag_diff_r
    hist_mag_diff_z[n]+=mag_diff_z
    hist_n[n]+=1

ra,dec = hp.pix2ang(128,np.arange(N), nest = True,lonlat = True)
col1 = fits.Column(name = 'ra', array = ra, format = 'D')
col2 = fits.Column(name = 'dec', array = dec, format = 'D')
col3 = fits.Column(name = 'num', array = hist_n, format = 'D')
col4 = fits.Column(name = 'hist_mag_diff_g', array = hist_mag_diff_g, format = 'D')
col5 = fits.Column(name = 'hist_mag_diff_r', array = hist_mag_diff_r, format = 'D')
col6 = fits.Column(name = 'hist_mag_diff_z', array = hist_mag_diff_z, format = 'D')

plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
dat = fits.BinTableHDU.from_columns([col1,col2,col3,col4,col5,col6]).data
sel = dat['num']
sel_num = (sel>0)
final = dat[sel_num]
hist_mag_diff_g_sel = final['hist_mag_diff_g']/final['num']
sel = (hist_mag_diff_g_sel>0.0)&(hist_mag_diff_g_sel<0.19)
super_final = final[sel]
sc = plt.scatter(super_final['ra'],super_final['dec'],c=super_final['hist_mag_diff_g']/super_final['num'])
plt.colorbar(sc)
plt.title('g mag diff')
plt.subplot(2,1,2)
pt = plt.hist(final['hist_mag_diff_g']/final['num'],bins = 50)
plt.title('g mag diff hist')
print((final['hist_mag_diff_g']/final['num']).mean(),(final['hist_mag_diff_g']/final['num']).std())
# Out:
# 0.0860308477628 0.0412782614013

# %%
plt.figure(figsize=(5,5))
plt.subplot(2,1,1)
pt = plt.hist(final['hist_mag_diff_r']/final['num'],bins = 50)
plt.title('r mag diff hist')
plt.subplot(2,1,2)
pt = plt.hist(final['hist_mag_diff_z']/final['num'],bins = 50)
plt.title('z mag diff hist')
plt.tight_layout()
print((final['hist_mag_diff_r']/final['num']).mean(),(final['hist_mag_diff_r']/final['num']).std())
print((final['hist_mag_diff_z']/final['num']).mean(),(final['hist_mag_diff_z']/final['num']).std())
# Out:
# 0.109951977433 0.0410207712277
# 0.0503539398996 0.0410748062149

# %%
#make correlation functions for x0
'''
I didn't use the code here, somehow it takes a long time to read 1000 txt files using numpy ~20min?,
slower on jupyter notebook. The output covariance matrix is save in the same directory, called 
cov_matrix.txt
'''
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros(len(x)*len(x)).reshape(len(x),len(x))
y_mean = 0

for i in range(1,1001):
    y_i = get(i)[1]
    y_mean+=y_i
y_mean = y_mean/1000.

for k in range(1,1001):
            y_k=get(k)[1]
            y+=np.outer(y_k-y_mean, y_k-y_mean)

# %%
#make error bars for x0
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[1]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

# %%
topdir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
fn_obiwan_weight = topdir+'elg_clustering_chunk23_w_edge_obiwan_weight_all_uniform.out'
fn_weight_systot = topdir+'elg_clustering_chunk23_w_edge_debug_uniform.out'
fn_uniform = topdir+'elg_clustering_chunk23_w_edge_uniform_all_uniform.out'
d4=np.loadtxt(fn_obiwan_weight).transpose()
d5=np.loadtxt(fn_weight_systot).transpose()
d6=np.loadtxt('/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/3d_corr/data/xi0gebossELG_NGC4_mz0.6xz1.1fkp8st0.dat').transpose()
d7=np.loadtxt(fn_uniform).transpose()
plt.plot(d4[0][:25],d4[1][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25],std_list*d5[0][:25]*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d6[0][:25],d6[1][:25]*d6[0][:25]*d6[0][:25],linestyle='--',label = 'original')
plt.plot(d7[0][:25],d7[1][:25],linestyle='--',label = 'uniform')
plt.legend()

plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r^2 \mathit{\xi_0(r)}$'+' '+r'$Mpc^2h^{-2}}$')
plt.title('ELG ngc chunk23')
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
#make correlation functions for x0
'''
I didn't use the code here, somehow it takes a long time to read 1000 txt files using numpy ~20min?,
slower on jupyter notebook. The output covariance matrix is save in the same directory, called 
cov_matrix.txt

update: I finally used it. It somehow wroks on jupyter quickly again
'''
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros(len(x)*len(x)).reshape(len(x),len(x))
y_mean = 0

for i in range(1,1001):
    y_i = get(i)[1]
    y_mean+=y_i
y_mean = y_mean/1000.

for k in range(1,1001):
            y_k=get(k)[1]
            y+=np.outer(y_k-y_mean, y_k-y_mean)

# %%
cov_mat = y/999.
x = np.loadtxt(fn_obiwan_weight).transpose()[0][:25]
obiwan_weight_dat = np.loadtxt(fn_obiwan_weight).transpose()[1][:25]
weight_systot_dat = np.loadtxt(fn_weight_systot).transpose()[1][:25]
diff = (obiwan_weight_dat-weight_systot_dat)/x/x

# %%
diff.dot(np.linalg.inv(cov_mat)).dot(diff)
#this is the chi2 I got for xi0
# Out:
# 3.930042173565357

# %%
plt.imshow(np.linalg.inv(cov_mat))

# %%
#make error bars for xi2
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

# %%
#xi2
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_clustering_chunk23_w_edge_obiwan_weight_all_uniform_order2.out'
corr5 = corr_dir+'elg_clustering_chunk23_w_edge_debug_uniform_order2.out'
corr6 = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/3d_corr/data/xi2gebossELG_eboss234_mz0.6xz1.1fkp8st0.dat'
corr7 = corr_dir+'elg_clustering_chunk23_w_edge_uniform_all_uniform_order2.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()
d6=np.loadtxt(corr6).transpose()
d7 = np.loadtxt(corr7).transpose()
plt.plot(d4[0][:25],d4[1][:25]*2/d4[0][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25]*2/d5[0][:25],std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*2/d7[0][:25],label='uniform',linestyle='--',marker='.')
#plt.errorbar(d6[0],d6[1]*d6[0],label='original',marker='.')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_2(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('elg NGC chunk23')
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
#make correlation functions for xi2
'''
I didn't use the code here, somehow it takes a long time to read 1000 txt files using numpy ~20min?,
slower on jupyter notebook. The output covariance matrix is save in the same directory, called 
cov_matrix.txt

update: I finally used it. It somehow wroks on jupyter quickly again
'''
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros(len(x)*len(x)).reshape(len(x),len(x))
y_mean = 0

for i in range(1,1001):
    y_i = get(i)[2]
    y_mean+=y_i
y_mean = y_mean/1000.

for k in range(1,1001):
            y_k=get(k)[1]
            y+=np.outer(y_k-y_mean, y_k-y_mean) 
cov_mat = y/999.

# %%
x = np.loadtxt(corr4).transpose()[0][:25]
obiwan_weight_dat = np.loadtxt(corr4).transpose()[1][:25]
weight_systot_dat = np.loadtxt(corr5).transpose()[1][:25]
diff = (obiwan_weight_dat-weight_systot_dat)/x/x

print(diff.dot(np.linalg.inv(cov_mat)).dot(diff))
# Out:
# 5.45072911529

# %%
#make error bars for xi4
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF2/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

# %%
#xi4
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_clustering_chunk23_w_edge_obiwan_weight_all_uniform_order4.out' #good
corr5 = corr_dir+'elg_clustering_chunk23_w_edge_debug_uniform_order4.out' #good
corr6 = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_code/py/obiwan/Drones/obiwan_analysis/3d_corr/data/xi2gebossELG_eboss234_mz0.6xz1.1fkp8st0.dat'
corr7 = corr_dir+'elg_clustering_chunk23_w_edge_uniform_all_uniform_order4.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()
d6=np.loadtxt(corr6).transpose()
d7 = np.loadtxt(corr7).transpose()
plt.plot(d4[0][:25],d4[1][:25]*2/d4[0][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25]*2/d5[0][:25],std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*2/d7[0][:25],label='uniform',linestyle='--',marker='.')
#plt.errorbar(d6[0],d6[1]*d6[0],label='original',marker='.')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_4(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('elg NGC chunk23')
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
#make correlation functions for xi4
'''
I didn't use the code here, somehow it takes a long time to read 1000 txt files using numpy ~20min?,
slower on jupyter notebook. The output covariance matrix is save in the same directory, called 
cov_matrix.txt

update: I finally used it. It somehow wroks on jupyter quickly again
'''
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF2/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros(len(x)*len(x)).reshape(len(x),len(x))
y_mean = 0

for i in range(1,1001):
    y_i = get(i)[2]
    y_mean+=y_i
y_mean = y_mean/1000.

for k in range(1,1001):
            y_k=get(k)[1]
            y+=np.outer(y_k-y_mean, y_k-y_mean) 
cov_mat = y/999.

# %%
x = np.loadtxt(corr4).transpose()[0][:25]
obiwan_weight_dat = np.loadtxt(corr4).transpose()[1][:25]
weight_systot_dat = np.loadtxt(corr5).transpose()[1][:25]
diff = (obiwan_weight_dat-weight_systot_dat)/x/x

print(diff.dot(np.linalg.inv(cov_mat)).dot(diff))
# Out:
# 4.25393912974

# %%
#make error bars for x0
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[1]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)


topdir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
fn_obiwan_weight = topdir+'elg_clustering_ngc_v5_uniform.out'
#fn_weight_systot = topdir+'elg_clustering_chunk23_v5_uniform.out'
#fn_uniform = topdir+'elg_clustering_chunk23_w_edge_uniform_all_uniform.out'
d4=np.loadtxt(fn_obiwan_weight).transpose()
#d5=np.loadtxt(fn_weight_systot).transpose()
d6=np.loadtxt(topdir+'origin_ashley.txt').transpose()
#d7=np.loadtxt(fn_uniform).transpose()
plt.plot(d4[0][:25],d4[1][:25],label='obiwan weight',linestyle='--',marker='.')
#plt.errorbar(d5[0][:25],d5[1][:25],std_list*d5[0][:25]*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d6[0][:25],d6[1][:25]*d6[0][:25]*d6[0][:25],linestyle='--',label = 'original')
#plt.plot(d7[0][:25],d7[1][:25],linestyle='--',label = 'uniform')
plt.legend()

plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r^2 \mathit{\xi_0(r)}$'+' '+r'$Mpc^2h^{-2}}$')
plt.title('ELG ngc chunk23')
# Out:
# Text(0.5,1,'ELG ngc chunk23')

# %%
#make error bars for x0
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[1]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)


topdir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
fn_obiwan_weight = topdir+'elg_clustering_chunk23_v5_obiwan_weight_uniform.out'
fn_weight_systot = topdir+'elg_clustering_chunk23_v5_uniform.out'
#fn_uniform = topdir+'elg_clustering_chunk23_w_edge_uniform_all_uniform.out'
d4=np.loadtxt(fn_obiwan_weight).transpose()
d5=np.loadtxt(fn_weight_systot).transpose()
d6=np.loadtxt(topdir+'origin_chunk23_ashley.txt').transpose()
#d7=np.loadtxt(fn_uniform).transpose()
plt.plot(d4[0][:25],d4[1][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25],std_list*d5[0][:25]*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d6[0][:25],d6[1][:25]*d6[0][:25]*d6[0][:25],linestyle='--',label = 'original')
#plt.plot(d7[0][:25],d7[1][:25],linestyle='--',label = 'uniform')
plt.legend()

plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r^2 \mathit{\xi_0(r)}$'+' '+r'$Mpc^2h^{-2}}$')
plt.title('ELG ngc chunk23')
# Out:
# Text(0.5,1,'ELG ngc chunk23')

# %%
plt.plot(d5[0][:25],d5[1][:25],label='weight systot',linestyle='--',marker='.')
plt.plot(d6[0][:25],d6[1][:25]*d6[0][:25]*d6[0][:25],linestyle='--',label = 'original')
plt.legend()

# %%
fn_weight_systot = topdir+'elg_clustering_chunk23_v5_uniform.out'
d6=np.loadtxt(topdir+'origin_ashley.txt').transpose()
d5=np.loadtxt(topdir+'origin_chunk23_ashley.txt').transpose()
d7=np.loadtxt(fn_weight_systot).transpose()
plt.plot(d5[0][:25],d5[1][:25]*d5[0][:25]*d5[0][:25],label='origin_chunk23',linestyle='--',marker='.')
plt.plot(d6[0][:25],d6[1][:25]*d6[0][:25]*d6[0][:25],linestyle='--',label = 'origin_ngc')
plt.plot(d7[0][:25],d7[1][:25],linestyle='--',label = 'weight_systot')
plt.legend()

# %%
fn_weight_systot = topdir+'elg_clustering_chunk23_v5_uniform.out'
d6=np.loadtxt(topdir+'origin_ashley.txt').transpose()
d5=np.loadtxt(topdir+'origin_chunk23_ashley.txt').transpose()
d7=np.loadtxt(fn_weight_systot).transpose()
plt.plot(d5[0],d5[1]*d5[0]*d5[0],label='origin_chunk23',linestyle='--',marker='.')
plt.plot(d6[0],d6[1]*d6[0]*d6[0],linestyle='--',label = 'origin_ngc')
plt.plot(d7[0],d7[1],linestyle='--',label = 'weight_systot',marker='.')
plt.legend()

# %%
d7[1]
# Out:
# array([ 16.6848308 ,  36.56812228,  40.35651293,  37.18356407,
#         32.54217696,  30.23970947,  23.03589104,  23.66256676,
#         31.50334912,  19.64424776,  12.54982223,   4.3783473 ,
#         -3.65833917,  -9.46896405, -13.80600748,  -6.01971793,
#        -17.67242051, -17.65557653, -43.77854739, -34.72705446,
#        -33.12718958, -13.61385284,   0.14037475,   8.10805457,
#          8.23104482,   3.33324842,  -5.66915724, -53.08941045,
#        -38.36548674, -21.69023736, -26.91978249])

# %%
d7[0]
# Out:
# array([   4.,   12.,   20.,   28.,   36.,   44.,   52.,   60.,   68.,
#          76.,   84.,   92.,  100.,  108.,  116.,  124.,  132.,  140.,
#         148.,  156.,  164.,  172.,  180.,  188.,  196.,  204.,  212.,
#         220.,  228.,  236.,  244.])

# %%
ss=[1.0428019249500051, 0.2539452935982201, 0.10089128231358398, 0.047428015398024749, 0.025109704442246871, 0.015619684643210697, 0.0085191904741994656, 0.0065729352117623102, 0.006813008028493106, 0.0034010124239562322, 0.0017786029231938898, 0.00051729055960593375, -0.00036583391682558114, -0.00081181104683947084, -0.0010260112576210133, -0.00039150090597386394, -0.0010142573752876221, -0.0009007947207047653, -0.0019986553774959822, -0.0014269828427026872, -0.001231677185413061, -0.00046017620477232325, 4.332554048916831e-06, 0.00022940398842388062, 0.00021426085028831697, 8.0095358129171715e-05, -0.00012613824403499217, -0.0010968886456001179, -0.00073802490641463464, -0.00038943976872188589, -0.00045215974347701492]

# %%
fn_weight_systot = topdir+'elg_clustering_chunk23_v5_uniform.out'
d6=np.loadtxt(topdir+'origin_ashley.txt').transpose()
d5=np.loadtxt(topdir+'origin_chunk23_ashley.txt').transpose()
d7=np.loadtxt(fn_weight_systot).transpose()
plt.plot(d5[0],d5[1]*d5[0]*d5[0],label='origin_chunk23',linestyle='--',marker='.')
#plt.plot(d6[0],d6[1]*d6[0]*d6[0],linestyle='--',label = 'origin_ngc')
plt.plot(d6[0],d7[1]*d6[0]*d6[0],linestyle='--',label = 'weight_systot',marker='.')
plt.legend()

# %%
fn_weight_systot = topdir+'elg_clustering_chunk23_v5_uniform_order2.out'
#d6=np.loadtxt(topdir+'origin_ashley.txt').transpose()
d5=np.loadtxt(topdir+'origin_chunk23_ashley.txt').transpose()
d7=np.loadtxt(fn_weight_systot).transpose()
#plt.plot(d5[0],d5[1]*d5[0]*d5[0],label='origin_chunk23',linestyle='--',marker='.')
#plt.plot(d6[0],d6[1]*d6[0]*d6[0],linestyle='--',label = 'origin_ngc')
plt.plot(d7[0],d7[1]*d7[0],linestyle='--',label = 'weight_systot',marker='.')
plt.legend()

# %%
np.savetxt(topdir+'x2.txt',d7[1])

# %%
elg_clustering_chunk23_v5_obiwan_weight_uniform.out
elg_clustering_chunk23_v5_obiwan_weight_uniform_order2.out
elg_clustering_chunk23_v5_obiwan_weight_uniform_order4.out
# Out:
# 'Daily_logs_May3-?.ipynb'  README.md  wonderful_plots.ipynb

# %%
#make error bars for x0
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[1]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)


topdir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
fn_obiwan_weight = topdir+'elg_clustering_chunk23_v5_obiwan_weight_uniform.out'
fn_weight_systot = topdir+'elg_clustering_chunk23_v5_uniform.out'
fn_uniform = topdir+'elg_clustering_chunk23_v5_uniform_uniform.out'
d4=np.loadtxt(fn_obiwan_weight).transpose()
d5=np.loadtxt(fn_weight_systot).transpose()
d6=np.loadtxt(topdir+'origin_chunk23_ashley.txt').transpose()
d7=np.loadtxt(fn_uniform).transpose()
plt.plot(d4[0][:25],d4[1][:25]*d4[0][:25]*d4[0][:25],label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25]*d5[0][:25]*d5[0][:25],std_list*d5[0][:25]*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d6[0][:25],d6[1][:25]*d6[0][:25]*d6[0][:25],linestyle='--',label = 'original')
plt.plot(d7[0][:25],d7[1][:25]*d7[0][:25]*d7[0][:25],linestyle='--',label = 'uniform')
plt.legend()

plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r^2 \mathit{\xi_0(r)}$'+' '+r'$Mpc^2h^{-2}}$')
plt.title('ELG ngc chunk23')
# Out:
# Text(0.5,1,'ELG ngc chunk23')

# %%
#make error bars for xi2
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

#xi2
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_clustering_chunk23_v5_obiwan_weight_uniform_order2.out'
corr5 = corr_dir+'elg_clustering_chunk23_v5_uniform_order2.out'
corr6 = corr_dir+'origin_chunk23_ashley.txt'
corr7 = corr_dir+'elg_clustering_chunk23_v5_uniform_uniform_order2.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()
d6=np.loadtxt(corr6).transpose()
d7 = np.loadtxt(corr7).transpose()
plt.plot(d4[0][:25],d4[1][:25]*d4[0][:25]*2,label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25]*d5[0][:25]*2,std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*d7[0][:25]*2,label='uniform',linestyle='--',marker='.')
plt.errorbar(d6[0][:25],d6[2][:25]*d6[0][:25],label='original',marker='.')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_2(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('elg NGC chunk23')
# Out:
# Text(0.5,1,'elg NGC chunk23')

# %%
#make error bars for xi4
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF2/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

#xi4
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_clustering_chunk23_v5_obiwan_weight_uniform_order4.out' #good
corr5 = corr_dir+'elg_clustering_chunk23_v5_uniform_order4.out'#good
corr6 = corr_dir +'origin_chunk23_ashley.txt'
corr7 = corr_dir+'elg_clustering_chunk23_v5_uniform_uniform_order4.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()
d6=np.loadtxt(corr6).transpose()
d7 = np.loadtxt(corr7).transpose()
plt.plot(d4[0][:25],d4[1][:25]*d4[0][:25]*2,label='obiwan weight',linestyle='--',marker='.')
plt.errorbar(d5[0][:25],d5[1][:25]*d5[0][:25]*2,std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*d7[0][:25]*2,label='uniform',linestyle='--',marker='.')
plt.errorbar(d6[0][:25],d6[3][:25]*d6[0][:25],label='original',marker='.')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_4(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('elg NGC chunk23')
# Out:
# Text(0.5,1,'elg NGC chunk23')

# %%
#combined -- final version
#make error bars for x0
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[1]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

# %%
plt.figure(figsize=(5,5))
topdir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
fn_obiwan_weight = topdir+'elg_ngc_run_conbimed_obiwan_weight_uniform_order0.out'
fn_weight_systot = topdir+'elg_ngc_run_conbimed_weight_systot_uniform_order0.out'
fn_uniform = topdir+'elg_ngc_run_conbimed_uniform_uniform_order0.out'
d4=np.loadtxt(fn_obiwan_weight).transpose()
d5=np.loadtxt(fn_weight_systot).transpose()
d6=np.loadtxt(topdir+'origin_chunk23_ashley.txt').transpose()
d7=np.loadtxt(fn_uniform).transpose()
plt.errorbar(d5[0][:25],d5[1][:25]*d5[0][:25]*d5[0][:25],std_list*d5[0][:25]*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d4[0][:25],d4[1][:25]*d4[0][:25]*d4[0][:25],label='obiwan weight',linestyle='--',marker='.')
#plt.plot(d6[0][:25],d6[1][:25]*d6[0][:25]*d6[0][:25],linestyle='--',label = 'original')
plt.plot(d7[0][:25],d7[1][:25]*d7[0][:25]*d7[0][:25],linestyle='--',label = 'uniform')
plt.legend()

plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r^2 \mathit{\xi_0(r)}$'+' '+r'$Mpc^2h^{-2}}$')
plt.title('ELG NGC chunk23')
plt.grid()
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
#make error bars for xi2
plt.figure(figsize=(5,5))
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

#xi2
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_ngc_run_conbimed_obiwan_weight_uniform_order2.out' #good
corr5 = corr_dir+'elg_ngc_run_conbimed_weight_systot_uniform_order2.out'#good
corr7 = corr_dir+'elg_ngc_run_conbimed_uniform_uniform_order2.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()

d7 = np.loadtxt(corr7).transpose()
plt.errorbar(d5[0][:25],d5[1][:25]*d5[0][:25]*2,std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d4[0][:25],d4[1][:25]*d4[0][:25]*2,label='obiwan weight',linestyle='--',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*d7[0][:25]*2,label='uniform',linestyle='--',marker='.')

plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_2(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('ELG NGC chunk23')
plt.grid()
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
plt.clf()
plt.figure(figsize=(5,5))
topdir0='/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/2PCF2/2PCF/'
def get(num,td = topdir0):
    f=np.loadtxt(topdir0+"2PCF_EZmock_eBOSS_ELG_eboss23GC_v4_z0.6z1.1_%04d.dat"%num).transpose()
    return f
x = get(1)[0]
y = np.zeros_like(x)
y_list=[]
for i in range(1,1001):
    y_i = get(i)[2]
    y+=y_i
    y_list.append(y_i)
y_list = np.array(y_list)
std_list = []
for i in range(len(y_list[0])):
    std_list.append(y_list[:,i].std())
std_list=np.array(std_list)

#xi4
corr_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/obiwan_corr/3d/corr_output/'
corr4 = corr_dir+'elg_ngc_run_conbimed_obiwan_weight_uniform.out' #good
corr5 = corr_dir+'elg_ngc_run_conbimed_weight_systot_uniform.out'#good
corr7 = corr_dir+'elg_ngc_run_conbimed_uniform_uniform.out'
d4=np.loadtxt(corr4).transpose()
d5=np.loadtxt(corr5).transpose()
d7 = np.loadtxt(corr7).transpose()

plt.errorbar(d5[0][:25],d5[1][:25]*d5[0][:25]*2,std_list*d5[0][:25],label='weight systot',linestyle='none',marker='.')
plt.plot(d4[0][:25],d4[1][:25]*d4[0][:25]*2,label='obiwan weight',linestyle='--',marker='.')
plt.plot(d7[0][:25],d7[1][:25]*d7[0][:25]*2,label='uniform',linestyle='--',marker='.')
plt.legend()
plt.xlabel('r '+r'$\mathit{Mpc} \cdot \mathit{h^{-1}}$')
plt.ylabel(r'$r \mathit{\xi_4(r)}$'+' '+r'$Mpch^{-1}}$')
plt.title('ELG NGC chunk23')
plt.grid()
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
# !pwd
# Out:
# /global/u2/h/huikong/obiwan_codes/obiwan_Aug/obiwan_code/py/ipynb

# %%
sim_elg_ngc_run_chunk23_really_masked_combined.fits

# %%
# !ls /global/u2/h/huikong/obiwan_out/
# Out:
# ls: cannot access '/global/u2/h/huikong/obiwan_out/': No such file or directory

# %%
# !ls /global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/subset/sim_elg_ngc_run_chunk23_really_masked_combined.fits
# Out:
# /global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/subset/sim_elg_ngc_run_chunk23_really_masked_combined.fits

# %%
import astropy.io.fits as fits
dat = fits.getdata('/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/subset/sim_elg_ngc_run_chunk23_really_masked_combined.fits')
len(dat)
# Out:
# 771639

# %%
topdir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/subset/'
len(fits.getdata((topdir+'eBOSS_ELG_full_ALL_v4.dat_really_masked_chunk23_elg_ngc_run_part1.fits')))
# Out:
# 76194

# %%
len(fits.getdata(topdir+'sim_elg_ngc_run_chunk23.fits'))
# Out:
# 612836

# %%
76194/771639
# Out:
# 0.09874306508613484

# %%
6159*200
# Out:
# 1231800

# %%
771639/1231800*3600
# Out:
# 2255.155382367267

# %%
612836*2
# Out:
# 1225672

# %%
1225672/1231800*3600
# Out:
# 3582.0905991232344
